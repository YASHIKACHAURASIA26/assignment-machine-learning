# %%
import numpy as np

# %%
a=np.random.randint(10,50,(6,5))
a
# Out:
# array([[10, 39, 35, 40, 13],
#        [33, 45, 11, 35, 24],
#        [41, 30, 39, 44, 26],
#        [49, 37, 26, 20, 44],
#        [46, 37, 22, 22, 23],
#        [19, 46, 40, 13, 46]])

# %%
a[3:5,:2]
# Out:
# array([[49, 37],
#        [46, 37]])

# %%
a[2:4,2:5]
# Out:
# array([[39, 44, 26],
#        [26, 20, 44]])
